# %%
import matplotlib.pyplot as plt
import math
from math import sin, cos
plt.plot?
x_cordi = []
y_cordi = []
x_new = []
y_new = []
for i in range(10):
    x_cordi.append(i)
    y_cordi.append(sin(i))
for i in range(10):
    x_new.append(i)
    y_new.append(cos(i))
plt.plot(x_cordi,y_cordi)
plt.plot(x_new, y_new)

plt.legend(['sinx','cosx'])

# %%
plt.figure()
plt.bar(x_new, y_new, width = 0.3)
# Out:
# <BarContainer object of 10 artists>

# %%
import numpy as np
plt.figure()
xvals = np.array([4,6,0,3,2])
yvals = np.array([2,3,0,6,4])
linear_x = np.array([1,2,3,4,5,6])
quadratic_y = linear_x**2
plt.bar(linear_x, quadratic_y, width = 0.3)
plt.bar(xvals,yvals, width = 0.3)
# Out:
# <BarContainer object of 5 artists>

# %%
import numpy as np
plt.figure()
xvals = np.array([4,6,0,3,2])
yvals = np.array([2,3,0,6,4])
linear_x = np.array([1,2,3,4,5,6])
quadratic_y = linear_x**2
plt.barh(linear_x, quadratic_y, height = 0.3)
plt.barh(xvals,yvals, height = 0.3)
# Out:
# <BarContainer object of 5 artists>

# %%
## Dejunkyfying a plot

# %%
## Data
import pandas as pd
pd.Series?
import numpy as np
data = {'Language': pd.Series(['Python', 'SQL', 'Java', 'C++', 'JavaScript']), '%Popularity': pd.Series([56,39,34,34,29])}
df = pd.DataFrame(data)
df
# Out:
#      Language  %Popularity
# 0      Python           56
# 1         SQL           39
# 2        Java           34
# 3         C++           34
# 4  JavaScript           29

# %%
plt.figure(frameon=False)
#x = df['Language']
#y = df['%Popularity']

# Other method to write x and y

x = np.array(['Python', 'SQL', 'Java', 'C++', 'JavaScript'])
y = np.array([56,39,34,34,29])
pos = np.arange(len(x))
plt.xlabel('Languages',)
plt.ylabel('Popularity Percentage')
plt.title('Top 5 Languages for Math & Data \nby % popularity on Stack Overflow', alpha=0.8)


# remove all the ticks (both axes), and tick labels on the Y axis
#plt.tick_params(top='off', bottom='off', left='off', right='off', labelleft='off', labelbottom='on')
plt.tick_params(labelleft='off')

#removing frame
plt.box(on=None)

for bar in bars:
    plt.gca().text(bar.get_x() + bar.get_width()/2, bar.get_height() - 5, str(int(bar.get_height())) + '%', 
                 ha='center', color='w', fontsize=11)
    
#change color to grey except pythons color
bars = plt.bar(x,y,width = 0.5, color = 'lightgrey')
bars[0].set_color('blue')

# %%
# Assignment - 2 Solution
